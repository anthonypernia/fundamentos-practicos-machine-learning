# %%
import pandas as pd

# %%
series = pd.Series([1,3,4,5,7,3,6,3,6])
series
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    7
# 5    3
# 6    6
# 7    3
# 8    6
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series[3]
# Out:
# 5

# %%
cad = pd.Series(['r','w','t','3','d'])
cad
# Out:
# 0    r
# 1    w
# 2    t
# 3    3
# 4    d
# dtype: object

# %%
lista = ['Hola', 'Mundo', 'Robotico']
df = pd.DataFrame(lista)
df
# Out:
#           0
# 0      Hola
# 1     Mundo
# 2  Robotico

# %%
data = {'Nombre': ['Juan','Antonio','Jose'], 'edad':[ 23,45,56 ], 'Pais':[ 'Venezuela','Brasil','Colombia' ]}

df = pd.DataFrame(data )
df
# Out:
#     Nombre  edad       Pais
# 0     Juan    23  Venezuela
# 1  Antonio    45     Brasil
# 2     Jose    56   Colombia

# %%
print( df[['Nombre','Pais']])
# Out:
#     Nombre       Pais
# 0     Juan  Venezuela
# 1  Antonio     Brasil
# 2     Jose   Colombia

# %%
data = pd.read_csv('canciones-2018.csv')

# %%
data.head()
# Out:
#                       id  ... time_signature
# 0  6DCZcSspjsKoFjzjrWoCd  ...            4.0
# 1  3ee8Jmje8o58CHK66QrVC  ...            4.0
# 2  0e7ipj03S05BNilyu5bRz  ...            4.0
# 3  3swc6WTsr7rl9DqQKQA55  ...            4.0
# 4  2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
#
# [5 rows x 16 columns]

# %%
data.name[3]
# Out:
# 'Psycho (feat. Ty Dolla $ign)'

# %%
data.artists[6]
# Out:
# 'Cardi B'

# %%
info = data.iloc[8]
info
# Out:
# id                  76cy1WJvNGJTj78UqeA5z
# name                                IDGAF
# artists                          Dua Lipa
# danceability                        0.836
# energy                              0.544
# key                                     7
# loudness                           -5.975
# mode                                    1
# speechiness                        0.0943
# acousticness                       0.0403
# instrumentalness                        0
# liveness                           0.0824
# valence                              0.51
# tempo                              97.028
# duration_ms                        217947
# time_signature                          4
# Name: 8, dtype: object

# %%
data.tail()
# Out:
#                        id  ... time_signature
# 95  630sXRhIcfwr2e4RdNtjK  ...            4.0
# 96  2xmrfQpmS2iJExTlklLoA  ...            4.0
# 97  5WvAo7DNuPRmk4APhdPzi  ...            5.0
# 98  1j4kHkkpqZRBwE0A4CN4Y  ...            4.0
# 99  3EPXxR3ImUwfayaurPi3c  ...            4.0
#
# [5 rows x 16 columns]

# %%
data.shape
# Out:
# (100, 16)

# %%
data.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
data['tempo'].describe()
# Out:
# count    100.000000
# mean     119.904180
# std       28.795984
# min       64.934000
# 25%       95.730750
# 50%      120.116000
# 75%      140.022750
# max      198.075000
# Name: tempo, dtype: float64

# %%
data.sort_index(axis=0, ascending=False)
# Out:
#                        id  ... time_signature
# 99  3EPXxR3ImUwfayaurPi3c  ...            4.0
# 98  1j4kHkkpqZRBwE0A4CN4Y  ...            4.0
# 97  5WvAo7DNuPRmk4APhdPzi  ...            5.0
# 96  2xmrfQpmS2iJExTlklLoA  ...            4.0
# 95  630sXRhIcfwr2e4RdNtjK  ...            4.0
# ..                    ...  ...            ...
# 4   2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
# 3   3swc6WTsr7rl9DqQKQA55  ...            4.0
# 2   0e7ipj03S05BNilyu5bRz  ...            4.0
# 1   3ee8Jmje8o58CHK66QrVC  ...            4.0
# 0   6DCZcSspjsKoFjzjrWoCd  ...            4.0
#
# [100 rows x 16 columns]
